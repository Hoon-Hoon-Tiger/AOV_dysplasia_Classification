# %%
from PIL import Image
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import numpy as np
import torchvision
from torchvision import transforms
from torchvision.utils import make_grid, save_image
from glob import glob
import cv2
import random

import shutil
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim
from torch.optim.lr_scheduler import StepLR
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score,plot_confusion_matrix

import time
import copy

# %%
def seed(seed = 42):
    random.seed(seed) # python random seed 고정
    os.environ['PYTHONHASHSEED'] = str(seed) # os 자체의 seed 고정
    np.random.seed(seed) # numpy seed 고정 
    torch.manual_seed(seed) # torch seed 고정
    torch.cuda.manual_seed(seed) # cudnn seed 고정
    torch.backends.cudnn.deterministic = True # cudnn seed 고정(nn.Conv2d)
    torch.backends.cudnn.benchmark = False # CUDA 내부 연산에서 가장 빠른 알고리즘을 찾아 수행

## DataLoader worker에 대한 seed 설정
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    numpy.random.seed(worker_seed)
    random.seed(worker_seed)
    
seed()

# %% [markdown]
# ## Model Load(SE_ResNet50(pretrained O))

# %%
from torchvision import models
import torch
import timm
# m = timm.create_model('seresnet50', pretrained=True)

seresnet50_pretrained = timm.create_model('seresnet50', pretrained=True)
print(seresnet50_pretrained)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
num_classes = 1
num_features = seresnet50_pretrained.fc.in_features
seresnet50_pretrained.fc = nn.Linear(num_features, num_classes)

seresnet50_pretrained
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(1024, 64, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(64, 1024, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (act1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (drop_block): Identity()
#       (act2): ReLU(inplace=True)
#       (aa): Identity()
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (se): SEModule(
#         (fc1): Conv2d(2048, 128, kernel_size=(1, 1), stride=(1, 1))
#         (bn): Identity()
#         (act): ReLU(inplace=True)
#         (fc2): Conv2d(128, 2048, kernel_size=(1, 1), stride=(1, 1))
#         (gate): Sigmoid()
#       )
#       (act3): ReLU(inplace=True)
#     )
#   )
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )

# %%
GPU_NUM = 0
os.environ["CUDA_VISIBLE_DEVICES"]='1'
print('gpu? ', torch.cuda.is_available())
device = torch.device(f'cuda:{GPU_NUM}' if torch.cuda.is_available() else 'cpu')
torch.cuda.set_device(device)
print('Current gpu: ', torch.cuda.current_device())

if device.type == 'cuda':
    print('Allocated:', round(torch.cuda.memory_allocated(GPU_NUM)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(GPU_NUM)/1024**3,1), 'GB')
    
model = seresnet50_pretrained.to(device)
x = torch.randn(3, 3, 224, 224).to(device)
output = model(x)
print(output)
# Out:
# gpu?  True
# Current gpu:  0
# Allocated: 0.0 GB
# Cached:    0.0 GB
# /home/crop2292/anaconda3/envs/hoon/lib/python3.6/site-packages/torch/cuda/memory.py:386: FutureWarning: torch.cuda.memory_cached has been renamed to torch.cuda.memory_reserved
#   FutureWarning)
# tensor([[-0.1496],
#         [ 0.0145],
#         [-0.2150]], device='cuda:0', grad_fn=<AddmmBackward0>)

# %%
# 8 : 1 : 1 
# model_name = 'seresnet50(b=16,Adam,Focal_alpha(0.75),WRS,sche,seed)_weights_pt'

# 7 : 1.5 : 1.5
model_name = 'seresnet50(b=16,Adam,Focal_alpha(0.75),WRS,sche,seed,7)_weights_pt'

model_path = '/mnt/nas100_vol2/LeeJungHoon/AOV_task(binary_clssification)/Model_V2/weights_file/'

# %%
model = seresnet50_pretrained.to(device)
model.load_state_dict(torch.load(model_path + model_name))
# Out:
# <All keys matched successfully>

# %%
pwd
# Out:
# '/mnt/nas100_vol2/LeeJungHoon/AOV_task(binary_clssification)/Model_V2/Grad_CAM_code'

# %%
# import datetime
# current_time = datetime.datetime.now() + datetime.timedelta(hours= 9)
# current_time = current_time.strftime('%Y-%m-%d-%H:%M')


saved_loc = os.path.join('/mnt/nas100_vol2/LeeJungHoon/AOV_task(binary_clssification)/Model_V2/Grad-CAM_results/Grad-CAM_results(seresnet50(b=16,Adam,Focal_alpha(0.75),WRS,sche,seed,7)_weights_pt)', )
if os.path.exists(saved_loc):
    shutil.rmtree(saved_loc)
os.mkdir(saved_loc)

print("결과 저장 위치: ", saved_loc)
# Out:
# 결과 저장 위치:  /mnt/nas100_vol2/LeeJungHoon/AOV_task(binary_clssification)/Model_V2/Grad-CAM_results/Grad-CAM_results(seresnet50(b=16,Adam,Focal_alpha(0.75),WRS,sche,seed,7)_weights_pt)

# %% [markdown]
# ## test dataset & test dataloader

# %%
#8 : 1 : 1 
'''
train_normal_path = '/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3/normal_train_v3/*.jpg'
train_abnormal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3/abnormal_train_v3/*.jpg'
valid_normal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3/normal_val_v3/*.jpg'
valid_abnormal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3/abnormal_val_v3/*.jpg'
test_normal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3/normal_test_v3/*.jpg'
test_abnormal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3/abnormal_test_v3/*.jpg'
'''

# %%
# 7 :1 :1
train_normal_path = '/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3(7_1.5_1.5)/normal_train_v3/*.jpg'
train_abnormal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3(7_1.5_1.5)/abnormal_train_v3/*.jpg'
valid_normal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3(7_1.5_1.5)/normal_val_v3/*.jpg'
valid_abnormal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3(7_1.5_1.5)/abnormal_val_v3/*.jpg'
test_normal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3(7_1.5_1.5)/normal_test_v3/*.jpg'
test_abnormal_path ='/mnt/nas100_vol2/LeeJungHoon/Aov_task_curation_data/curation_data_v3/data_v3(7_1.5_1.5)/abnormal_test_v3/*.jpg'

# %%
train_normal_glob = glob(train_normal_path)
train_abnormal_glob = glob(train_abnormal_path)
val_normal_glob = glob(valid_normal_path)
val_abnormal_glob = glob(valid_abnormal_path)
test_normal_glob = glob(test_normal_path)
test_abnormal_glob = glob(test_abnormal_path)

print('train_normal :', len(train_normal_glob))
print('val_normal :', len(val_normal_glob))
print('test_normal :', len(test_normal_glob))
print('------------------------------------')
print('train_abnormal :', len(train_abnormal_glob))
print('val_abnormal :', len(val_abnormal_glob))
print('test_abnormal :', len(test_abnormal_glob))
# Out:
# train_normal : 406
# val_normal : 92
# test_normal : 92
# ------------------------------------
# train_abnormal : 234
# val_abnormal : 51
# test_abnormal : 46

# %%
class Aov_Dysplasia_dataset(Dataset):
    def __init__(self, normal_path, abnormal_path, transform=None):
        #생성자, 데이터를 전처리 
        self.normal_path_list = glob(normal_path)
        self.abnormal_path_list = glob(abnormal_path)
        # print(len(self.normal_path_list))
#         self.mode = mode 
    
#         label = np.array([[0, 1], [1, 0]], dtype=np.float32)
        
#         self.label_list = []
#         for i in self.normal_path_list:
#             self.label_list.append(label[0])
            
#         for i in self.abnormal_path_list:
#             self.label_list.append(label[1])
            
        label_policy = {
            'normal': 0, 
            'abnormal': 1
        }
    
        self.label_list= []
        
        for i in self.normal_path_list:
            self.label_list.append(label_policy["normal"])
            
        for i in self.abnormal_path_list:
            self.label_list.append(label_policy["abnormal"])
        
        self.total_img_path_list = self.normal_path_list + self.abnormal_path_list
        print(len(self.total_img_path_list))
        self.transform = transform
    
    def __len__(self):
        return len(self.total_img_path_list)
    
    def __getitem__(self, idx):
        
        img = cv2.imread(self.total_img_path_list[idx])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        # img = np.array(img, dtype=np.float32)
        #들어오는 이미지의 컬러 형태가 BGR인지 RGB인지 모르기때문에 변형

        
        label = self.label_list[idx]
        
        if self.transform is not None:
            transformed = self.transform(image=img)
            img = transformed['image'] 
            img = torch.tensor(np.array(img), dtype=torch.float32)
            # img = torch.FloatTensor(img)
            img = (img - torch.min(img)) / (torch.max(img)-torch.min(img))
            
            return {'img': img, 'label': label, 'filename': self.total_img_path_list[idx]}
        
        else:
            # img = transformed['image']
            img = torch.tensor(np.array(img), dtype=torch.float32)
            # img = torch.FloatTensor(img)
            img = (img - torch.min(img)) / (torch.max(img)-torch.min(img))
            return{'img': img, 'label': label}

# %%
#https://albumentations.ai/docs/api_reference/augmentations/transforms/
import albumentations as A 
from  albumentations.pytorch import ToTensorV2

test_transform = A.Compose(
    [
        A.Resize(224,224, interpolation = cv2.INTER_AREA),
        ToTensorV2()
    ])

# %%
test_dataset = Aov_Dysplasia_dataset(test_normal_path, test_abnormal_path, transform = test_transform)
# Out:
# 138

# %%
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=1, shuffle = False ,worker_init_fn=seed_worker)

# %%
len(test_dataloader.dataset)
# Out:
# 138

# %%
# final conv layer name 
# feature map을 추출할 layer를 설정
finalconv_name = 'layer4'

# inference mode
model.eval()

# number of result
# num_result = 10


feature_blobs = []

backward_feature = []

# output으로 나오는 feature를 feature_blobs에 append하도록
def hook_feature(module, input, output):
    feature_blobs.append(output.cpu().data.numpy())
    
# Grad-CAM
def backward_hook(module, input, output):
    backward_feature.append(output[0])

    
model._modules.get(finalconv_name).register_forward_hook(hook_feature)
model._modules.get(finalconv_name).register_backward_hook(backward_hook)


# get the sigmoid weight
params = list(model.parameters())
weight_sigmoid = np.squeeze(params[-2].cpu().detach().numpy()) # [1, 512]


# generate the class activation maps
def returnCAM(feature_conv, weight_simoid, class_idx):
    size_upsample = (224, 224)
    _, nc, h, w = feature_conv.shape # nc : number of channel, h: height, w: width
    output_cam = []
    # weight 중에서 class index에 해당하는 것만 뽑은 다음, 이를 conv feature와 곱연산
    cam = weight_sigmoid[class_idx].dot(feature_conv.reshape((nc, h*w))) 
    cam = cam.reshape(h, w)
    cam = cam - np.min(cam)
    cam_img = cam / np.max(cam)
    cam_img = np.uint8(255 * cam_img)
    output_cam.append(cv2.resize(cam_img, size_upsample))
    return output_cam


incorrect_abnormal_list =[]
incorrect_normal_list = []

for data in test_dataloader:
    
    inputs = data['img'].float()
    labels = data['label']
    idx_list = data['filename']
    idx = ' '.join(s for s in idx_list)
    idx = idx.split('/')[-1]
    
    # 모델의 input으로 주기 위한 image는 따로 설정
    image_for_model = inputs.clone().detach()

    # Image denormalization, using mean and std that i was used.
#     image[0][0] *= 0.2257
#     image[0][1] *= 0.2209
#     image[0][2] *= 0.2212
    
#     image[0][0] += 0.4876
#     image[0][1] += 0.4544
#     image[0][2] += 0.4165
    

    # 모델의 input으로 사용하도록.
    image_tensor = image_for_model.to(device)
    logit = model(image_tensor)
    output = torch.squeeze(logit)
    output_sig = torch.sigmoid(output)
    y_pred = output_sig.cpu()
    print(y_pred)
    y_pred[y_pred >= 0.5] = 1
    y_pred[y_pred < 0.5] = 0
    
    if y_pred != labels.cpu():
        
        if labels.cpu() == 1:
            incorrect_abnormal_list.append(idx)
        else:
            incorrect_normal_list.append(idx)
    label_out = labels.item()
    y_pred_out = y_pred.item()
    print("True label : %d, Predicted label : %d, idx : %s" % (label_out, y_pred_out, idx))
    
    # ============================= #
    # ==== Grad-CAM main lines ==== #
    # ============================= #
    
    score = logit.squeeze() # 예측값 y^c
    score.backward(retain_graph = True) # 예측값 y^c에 대해서 backprop 진행
    
    activations = torch.Tensor(feature_blobs[0]).to(device) # (1, 512, 7, 7), forward activations
    gradients = backward_feature[0] # (1, 512, 7, 7), backward gradients
    b, k, u, v = gradients.size()
    
    # view() 함수에서 -1은 다른 dimension에서 자동적으로 추론되는 것을 의미한다. 
    alpha = gradients.view(b, k, -1).mean(2) # (1, 512, 7*7) => (1, 512), feature map k의 'importance'
    weights = alpha.view(b, k, 1, 1) # (1, 512, 1, 1)
    
    #위에서 지정해준 layer에서의 output인 activations과 backward gradients를 평균한 값인 weights를 곱해준다.
    grad_cam_map = (weights*activations).sum(1, keepdim = True) # alpha * A^k = (1, 512, 7, 7) => (1, 1, 7, 7)
    
    # Apply R e L U
    grad_cam_map = F.relu(grad_cam_map) 
    
    grad_cam_map = F.interpolate(grad_cam_map, size=(224, 224), mode='bilinear', align_corners=False) # (1, 1, 224, 224)
    map_min, map_max = grad_cam_map.min(), grad_cam_map.max()
    grad_cam_map = (grad_cam_map - map_min).div(map_max - map_min).data # (1, 1, 224, 224), min-max scaling

    # grad_cam_map.squeeze() : (224, 224)
    grad_heatmap = cv2.applyColorMap(np.uint8(255 * grad_cam_map.squeeze().cpu()), cv2.COLORMAP_JET) # (224, 224, 3), numpy 
    grad_heatmap = torch.from_numpy(grad_heatmap).permute(2, 0, 1).float().div(255) # (3, 224, 224)
    b, g, r = grad_heatmap.split(1)
    grad_heatmap = torch.cat([r, g, b]) # (3, 244, 244), opencv's default format is BGR, so we need to change it as RGB format.

    # save_image(grad_heatmap, os.path.join(saved_loc, "%d_%d_%s" % (label_out, y_pred_out, idx_out)))
    
    # print(grad_heatmap.type)
    # print(inputsinputs.cpu().type)
    grad_result = grad_heatmap + inputs.cpu() # (1, 3, 224, 224)
    # print(grad_result.shape)
    grad_result = grad_result.div(grad_result.max()).squeeze() # (3, 224, 224)
    
    # save_image(grad_result, os.path.join(saved_loc, "GradCAM&image_%d.jpg" % (xhch_idx+1)))
    
    
    image_list = []
    
    image_list.append(torch.stack([inputs.squeeze().cpu(), grad_result], 0)) # (3, 3, 224, 224)
    
    images = make_grid(torch.cat(image_list, 0), nrow = 2)
    
    # image 저장
    save_image(images, os.path.join(saved_loc, "%d_%d_%s" % (label_out, y_pred_out, idx)))
    
    # if  batch_idx + 1 == num_result:
    #     break
        
    feature_blobs.clear()
    backward_feature.clear()

feature_blobs.clear()
backward_feature.clear()
# Out:
# /home/crop2292/anaconda3/envs/hoon/lib/python3.6/site-packages/torch/nn/modules/module.py:1025: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "
# tensor(0.0232, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10524154__2020-03-09__205d.jpg
# tensor(0.0108, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10524154__2020-03-09__305d.jpg
# tensor(0.0525, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10524154__2020-03-09__05d.jpg
# tensor(0.1914, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10626726__2020-12-17__05d.jpg
# tensor(0.0258, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10626726__2022-01-04__205d.jpg
# tensor(0.0149, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10626726__2022-01-04__05d.jpg
# tensor(0.1274, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10794302__2020-06-11__205d.jpg
# tensor(0.1031, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10794302__2020-06-11__05d.jpg
# tensor(0.0659, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10794302__2021-06-04__05d.jpg
# tensor(0.0919, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10801899__2018-12-01__05d.jpg
# tensor(0.2021, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11111405__2019-12-06__05d.jpg
# tensor(0.0059, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11254775__2021-01-19__205d.jpg
# tensor(0.3890, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11254775__2021-01-19__05d.jpg
# tensor(0.1244, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11254775__2022-01-18__05d.jpg
# tensor(0.1500, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11362126__2021-05-14__05d.jpg
# tensor(0.6457, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 11430795__2013-07-17__05d.jpg
# tensor(0.1722, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11430795__2015-07-15__05d.jpg
# tensor(0.6853, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 11492647__2019-01-18__05d.jpg
# tensor(0.1468, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11626084__2015-04-10__05d.jpg
# tensor(0.0363, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11756341__2022-04-28__05d.jpg
# tensor(0.2996, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11977643__2019-01-02__05d.jpg
# tensor(0.2630, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 12113675__2019-09-21__05d.jpg
# tensor(0.7716, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 12772478__2017-04-04__205d.jpg
# tensor(0.9132, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 12772478__2017-04-04__05d.jpg
# tensor(0.0888, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 12772478__2021-03-03__205d.jpg
# tensor(0.7983, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 12772478__2021-03-03__05d.jpg
# tensor(0.0782, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 12908385__2022-04-27__05d.jpg
# tensor(0.7180, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 13013297__2019-02-01__05d.jpg
# tensor(0.0325, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13013297__2021-09-17__05d.jpg
# tensor(0.0813, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13061359__2018-07-26__05d.jpg
# tensor(0.0166, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13259769__2020-05-21__05d.jpg
# tensor(0.0204, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13259769__2021-05-25__205d.jpg
# tensor(0.0996, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13259769__2021-05-25__05d.jpg
# tensor(0.2581, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 14015241__2021-06-16__205d.jpg
# tensor(0.0970, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 14015241__2021-06-16__05d.jpg
# tensor(0.7783, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 14309458__2019-04-17__05d.jpg
# tensor(0.0243, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 14309458__2020-04-17__05d.jpg
# tensor(0.0217, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 14309458__2021-04-20__05d.jpg
# tensor(0.9286, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 14312168__2019-03-16__05d.jpg
# tensor(0.5179, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 14312168__2020-02-08__05d.jpg
# tensor(0.0988, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 15273273__2022-04-18__205d.jpg
# tensor(0.1540, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 15273273__2022-04-18__05d.jpg
# tensor(0.6318, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 15329703__2019-06-19__05d.jpg
# tensor(0.0200, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 15809038__2022-04-18__05d.jpg
# tensor(0.1539, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 15901941__2017-04-07__05d.jpg
# tensor(0.0557, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 15901941__2019-05-23__05d.jpg
# tensor(0.0107, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 15901941__2021-06-30__05d.jpg
# tensor(0.8982, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 16602519__2019-05-17__205d.jpg
# tensor(0.7519, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 16602519__2019-05-17__05d.jpg
# tensor(0.1494, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 16602519__2020-06-22__05d.jpg
# tensor(0.0131, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 16602519__2021-05-21__05d.jpg
# tensor(0.1234, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 16787643__2016-01-09__205d.jpg
# tensor(0.2615, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 16787643__2016-01-09__05d.jpg
# tensor(0.0791, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 16787643__2018-07-16__05d.jpg
# tensor(0.3445, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 16924860__2019-08-27__05d.jpg
# tensor(0.0058, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 16924860__2020-08-18__05d.jpg
# tensor(0.0211, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 16924860__2021-08-21__05d.jpg
# tensor(0.0267, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 17644150__2020-03-05__05d.jpg
# tensor(0.0897, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 28069425__2022-05-06__05d.jpg
# tensor(0.0506, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 28459299__2022-04-28__05d.jpg
# tensor(0.6310, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 29432420__2022-03-08__05d.jpg
# tensor(0.0611, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 29536601__2022-04-18__05d.jpg
# tensor(0.0156, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 33664062__2022-04-27__05d.jpg
# tensor(0.0150, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 33859877__2022-04-27__05d.jpg
# tensor(0.0861, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 34063934__2022-05-06__05d.jpg
# tensor(0.2136, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 36589324__2022-04-27__05d.jpg
# tensor(0.7950, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 39910198__2022-04-27__05d.jpg
# tensor(0.1630, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 42396224__2022-04-18__205d.jpg
# tensor(0.2521, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 42396224__2022-04-18__05d.jpg
# tensor(0.0769, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 43603901__2022-04-27__05d.jpg
# tensor(0.2364, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 43704563__2022-04-28__05d.jpg
# tensor(0.0254, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 47154850__2021-05-28__05d.jpg
# tensor(0.4164, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 47154850__2022-05-06__05d.jpg
# tensor(0.3449, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 52747177__2022-04-18__05d.jpg
# tensor(0.0717, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 53787332__2020-02-08__205d.jpg
# tensor(0.1617, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 53787332__2020-02-08__05d.jpg
# tensor(0.0424, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 53787332__2022-05-06__205d.jpg
# tensor(0.0289, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 53787332__2022-05-06__05d.jpg
# tensor(0.0120, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 54045916__2021-03-23__05d.jpg
# tensor(0.0147, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 54045916__2022-05-06__05d.jpg
# tensor(0.0552, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 57416269__2020-11-30__05d.jpg
# tensor(0.2495, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 57416269__2022-05-06__05d.jpg
# tensor(0.6703, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 62114332__2021-09-03__05d.jpg
# tensor(0.0668, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 62116725__2021-09-06__05d.jpg
# tensor(0.4563, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 62202936__2021-09-27__05d.jpg
# tensor(0.0402, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 62550510__2022-04-18__205d.jpg
# tensor(0.0568, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 62550510__2022-04-18__05d.jpg
# tensor(0.1736, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 62551049__2022-04-18__05d.jpg
# tensor(0.1151, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 62663896__2022-03-08__05d.jpg
# tensor(0.0562, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 62975018__2022-04-27__05d.jpg
# tensor(0.1234, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 63512162__2022-04-18__05d.jpg
# tensor(0.0345, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10835450__2022-02-10__05d.jpg
# tensor(0.7261, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 11725493__2017-04-11__205d.jpg
# tensor(0.2120, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 11725493__2017-04-11__305d.jpg
# tensor(0.3872, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 11725493__2017-04-11__05d.jpg
# tensor(0.5098, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 13562915__2017-03-20_205d.jpg
# tensor(0.7748, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 13562915__2017-03-20_05d.jpg
# tensor(0.9824, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 29623233__2020-08-26__205d.jpg
# tensor(0.9463, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 29623233__2020-08-26__05d.jpg
# tensor(0.4642, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 30497155__2016-10-07__205d.jpg
# tensor(0.4595, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 43804735__2017-05-17__205d.jpg
# tensor(0.9905, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 43804735__2017-05-17__05d.jpg
# tensor(0.8726, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 44983321__2016-04-27_205d.jpg
# tensor(0.9767, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 44983321__2016-04-27_305d.jpg
# tensor(0.9252, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 44983321__2016-04-27_405d.jpg
# tensor(0.9942, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 44983321__2016-04-27_505d.jpg
# tensor(0.9880, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 44983321__2016-04-27_605d.jpg
# tensor(0.9626, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 44983321__2016-04-27_05d.jpg
# tensor(0.8878, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 49157994__2017-10-11__05d.jpg
# tensor(0.9854, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 50526879__2016-02-12__205d.jpg
# tensor(0.9867, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 50526879__2016-02-12__05d.jpg
# tensor(0.9925, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 51932617__2019-05-16__205d.jpg
# tensor(0.9545, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 51932617__2019-05-16__305d.jpg
# tensor(0.9842, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 51932617__2019-05-16__405d.jpg
# tensor(0.9556, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 51932617__2019-05-16__05d.jpg
# tensor(0.9953, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 52272806__2017-01-17__205d.jpg
# tensor(0.9403, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 52272806__2017-01-17__05d.jpg
# tensor(0.9731, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 53642059__2019-01-10__205d.jpg
# tensor(0.8128, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 53642059__2019-01-10__305d.jpg
# tensor(0.9747, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 53642059__2019-01-10__405d.jpg
# tensor(0.9261, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 53642059__2019-01-10__505d.jpg
# tensor(0.8590, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 53642059__2019-01-10__605d.jpg
# tensor(0.6076, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 53642059__2019-01-10__05d.jpg
# tensor(0.6751, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 54722787__2018-06-15__205d.jpg
# tensor(0.3860, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 54722787__2018-06-15__05d.jpg
# tensor(0.3742, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 59055350__2020-05-18__05d.jpg
# tensor(0.8986, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 61960967__2021-09-08__205d.jpg
# tensor(0.1828, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 61960967__2021-09-08__305d.jpg
# tensor(0.9787, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 61960967__2021-09-08__05d.jpg
# tensor(0.9987, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 10535370__2016-11-07__305d.jpg
# tensor(0.9592, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 26228886__2022-04-25__205d.jpg
# tensor(0.8438, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 26228886__2022-04-25__05d.jpg
# tensor(0.8873, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 62396514__2021-10-18__205d.jpg
# tensor(0.8329, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 62396514__2021-10-18__305d.jpg
# tensor(0.0884, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 62396514__2021-10-18__05d.jpg
# tensor(0.7288, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 62396514__2022-05-28__05d.jpg
# tensor(0.9585, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 12311811__2022-07-12__205d.jpg
# tensor(0.8985, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 12311811__2022-07-12__05d.jpg

# %% [markdown]
# ## validation dataset에 대한 Grad-CAM 확인

# %%
# import datetime
# current_time = datetime.datetime.now() + datetime.timedelta(hours= 9)
# current_time = current_time.strftime('%Y-%m-%d-%H:%M')


saved_loc = os.path.join('/mnt/nas100_vol2/LeeJungHoon/AOV_task(binary_clssification)/Model_V2/Grad-CAM_results/Grad-CAM_results(Resnet_Focal(0.75)_WRS_sch_validation)', )
if os.path.exists(saved_loc):
    shutil.rmtree(saved_loc)
os.mkdir(saved_loc)

print("결과 저장 위치: ", saved_loc)
# Out:
# 결과 저장 위치:  /mnt/nas100_vol2/LeeJungHoon/AOV_task(binary_clssification)/Model_V2/Grad-CAM_results/Grad-CAM_results(Resnet_Focal(0.75)_WRS_sch_validation)

# %%
valid_dataloader = torch.utils.data.DataLoader(valid_dataset, batch_size=1, shuffle = False, worker_init_fn=seed_worker)

# %%
# final conv layer name 
# feature map을 추출할 layer를 설정
finalconv_name = 'layer4'

# inference mode
model.eval()

# number of result
# num_result = 10


feature_blobs = []

backward_feature = []

# output으로 나오는 feature를 feature_blobs에 append하도록
def hook_feature(module, input, output):
    feature_blobs.append(output.cpu().data.numpy())
    
# Grad-CAM
def backward_hook(module, input, output):
    backward_feature.append(output[0])

    
model._modules.get(finalconv_name).register_forward_hook(hook_feature)
model._modules.get(finalconv_name).register_backward_hook(backward_hook)


# get the sigmoid weight
params = list(model.parameters())
weight_sigmoid = np.squeeze(params[-2].cpu().detach().numpy()) # [1, 512]


# generate the class activation maps
def returnCAM(feature_conv, weight_simoid, class_idx):
    size_upsample = (224, 224)
    _, nc, h, w = feature_conv.shape # nc : number of channel, h: height, w: width
    output_cam = []
    # weight 중에서 class index에 해당하는 것만 뽑은 다음, 이를 conv feature와 곱연산
    cam = weight_sigmoid[class_idx].dot(feature_conv.reshape((nc, h*w))) 
    cam = cam.reshape(h, w)
    cam = cam - np.min(cam)
    cam_img = cam / np.max(cam)
    cam_img = np.uint8(255 * cam_img)
    output_cam.append(cv2.resize(cam_img, size_upsample))
    return output_cam


incorrect_abnormal_list =[]
incorrect_normal_list = []

for data in valid_dataloader:
    
    inputs = data['img'].float()
    labels = data['label']
    idx_list = data['filename']
    idx = ' '.join(s for s in idx_list)
    idx = idx.split('/')[-1]
    
    # 모델의 input으로 주기 위한 image는 따로 설정
    image_for_model = inputs.clone().detach()

    # Image denormalization, using mean and std that i was used.
#     image[0][0] *= 0.2257
#     image[0][1] *= 0.2209
#     image[0][2] *= 0.2212
    
#     image[0][0] += 0.4876
#     image[0][1] += 0.4544
#     image[0][2] += 0.4165
    

    # 모델의 input으로 사용하도록.
    image_tensor = image_for_model.to(device)
    logit = model(image_tensor)
    output = torch.squeeze(logit)
    output_sig = torch.sigmoid(output)
    y_pred = output_sig.cpu()
    print(y_pred)
    y_pred[y_pred >= 0.5] = 1
    y_pred[y_pred < 0.5] = 0
    
    if y_pred != labels.cpu():
        
        if labels.cpu() == 1:
            incorrect_abnormal_list.append(idx)
        else:
            incorrect_normal_list.append(idx)
    label_out = labels.item()
    y_pred_out = y_pred.item()
    print("True label : %d, Predicted label : %d, idx : %s" % (label_out, y_pred_out, idx))
    
    # ============================= #
    # ==== Grad-CAM main lines ==== #
    # ============================= #
    
    score = logit.squeeze() # 예측값 y^c
    score.backward(retain_graph = True) # 예측값 y^c에 대해서 backprop 진행
    
    activations = torch.Tensor(feature_blobs[0]).to(device) # (1, 512, 7, 7), forward activations
    gradients = backward_feature[0] # (1, 512, 7, 7), backward gradients
    b, k, u, v = gradients.size()
    
    # view() 함수에서 -1은 다른 dimension에서 자동적으로 추론되는 것을 의미한다. 
    alpha = gradients.view(b, k, -1).mean(2) # (1, 512, 7*7) => (1, 512), feature map k의 'importance'
    weights = alpha.view(b, k, 1, 1) # (1, 512, 1, 1)
    
    #위에서 지정해준 layer에서의 output인 activations과 backward gradients를 평균한 값인 weights를 곱해준다.
    grad_cam_map = (weights*activations).sum(1, keepdim = True) # alpha * A^k = (1, 512, 7, 7) => (1, 1, 7, 7)
    
    # Apply R e L U
    grad_cam_map = F.relu(grad_cam_map) 
    
    grad_cam_map = F.interpolate(grad_cam_map, size=(224, 224), mode='bilinear', align_corners=False) # (1, 1, 224, 224)
    map_min, map_max = grad_cam_map.min(), grad_cam_map.max()
    grad_cam_map = (grad_cam_map - map_min).div(map_max - map_min).data # (1, 1, 224, 224), min-max scaling

    # grad_cam_map.squeeze() : (224, 224)
    grad_heatmap = cv2.applyColorMap(np.uint8(255 * grad_cam_map.squeeze().cpu()), cv2.COLORMAP_JET) # (224, 224, 3), numpy 
    grad_heatmap = torch.from_numpy(grad_heatmap).permute(2, 0, 1).float().div(255) # (3, 224, 224)
    b, g, r = grad_heatmap.split(1)
    grad_heatmap = torch.cat([r, g, b]) # (3, 244, 244), opencv's default format is BGR, so we need to change it as RGB format.

    # save_image(grad_heatmap, os.path.join(saved_loc, "%d_%d_%s" % (label_out, y_pred_out, idx_out)))
    
    # print(grad_heatmap.type)
    # print(inputsinputs.cpu().type)
    grad_result = grad_heatmap + inputs.cpu() # (1, 3, 224, 224)
    # print(grad_result.shape)
    grad_result = grad_result.div(grad_result.max()).squeeze() # (3, 224, 224)
    
    # save_image(grad_result, os.path.join(saved_loc, "GradCAM&image_%d.jpg" % (xhch_idx+1)))
    
    
    image_list = []
    
    image_list.append(torch.stack([inputs.squeeze().cpu(), grad_heatmap, grad_result], 0)) # (3, 3, 224, 224)
    
    images = make_grid(torch.cat(image_list, 0), nrow = 3)
    
    # image 저장
    save_image(images, os.path.join(saved_loc, "%d_%d_%s" % (label_out, y_pred_out, idx)))
    
    # if  batch_idx + 1 == num_result:
    #     break
        
    feature_blobs.clear()
    backward_feature.clear()

feature_blobs.clear()
backward_feature.clear()
# Out:
# tensor(0.4185, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10522963__2018-12-27__05d.jpg
# tensor(0.2730, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10781135__2020-02-26__05d.jpg
# tensor(0.4659, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10794302__2020-06-11__205d.jpg
# tensor(0.1549, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10794302__2020-06-11__05d.jpg
# tensor(0.0538, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10794302__2021-06-04__05d.jpg
# tensor(0.5989, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 10898019__2019-07-09__05d.jpg
# tensor(0.0431, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10904750__2019-01-30__05d.jpg
# tensor(0.0731, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 10904750__2020-01-06__05d.jpg
# tensor(0.3107, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11141057__2019-05-14__05d.jpg
# tensor(0.0189, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11141057__2021-09-02__05d.jpg
# tensor(0.4457, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 11472124__2017-11-29__05d.jpg
# tensor(0.3340, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13229441__2021-05-07__05d.jpg
# tensor(0.2880, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13233262__2018-02-28__05d.jpg
# tensor(0.6425, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 13233262__2019-02-26__05d.jpg
# tensor(0.1733, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13233262__2021-04-02__05d.jpg
# tensor(0.1635, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13653532__2016-10-04__05d.jpg
# tensor(0.0714, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13653532__2019-02-11__05d.jpg
# tensor(0.1092, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13830416__2016-02-23__05d.jpg
# tensor(0.0793, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13830416__2018-02-27__05d.jpg
# tensor(0.5421, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 13989402__2018-06-18__05d.jpg
# tensor(0.1070, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 13989402__2021-06-28__05d.jpg
# tensor(0.0793, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 14186624__2021-08-03__05d.jpg
# tensor(0.9908, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 14309458__2019-04-17__05d.jpg
# tensor(0.0466, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 14309458__2020-04-17__05d.jpg
# tensor(0.0110, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 14309458__2021-04-20__05d.jpg
# tensor(0.0341, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 14485136__2022-04-28__05d.jpg
# tensor(0.2582, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 17146144__2021-09-01__05d.jpg
# tensor(0.0089, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 18156409__2022-04-27__05d.jpg
# tensor(0.1319, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 19590019__2020-02-10__05d.jpg
# tensor(0.0247, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 19590019__2021-05-14__05d.jpg
# tensor(0.5150, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 19590019__2022-05-06__205d.jpg
# tensor(0.1091, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 19590019__2022-05-06__05d.jpg
# tensor(0.0185, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 23500673__2022-03-08__05d.jpg
# tensor(0.0404, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 24679899__2022-04-27__05d.jpg
# tensor(0.0209, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 29349092__2022-04-28__05d.jpg
# tensor(0.0468, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 29970799__2022-04-18__05d.jpg
# tensor(0.1354, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 31740186__2022-04-18__05d.jpg
# tensor(0.0061, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 33664062__2022-04-27__05d.jpg
# tensor(0.0128, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 33765112__2022-04-18__05d.jpg
# tensor(0.1698, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 34860483__2022-05-06__05d.jpg
# tensor(0.2224, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 42268381__2022-04-27__05d.jpg
# tensor(0.1475, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 45035768__2019-05-31__05d.jpg
# tensor(0.0688, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 45035768__2022-05-06__05d.jpg
# tensor(0.0493, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 48219899__2022-04-27__05d.jpg
# tensor(0.1653, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 50642416__2022-04-18__05d.jpg
# tensor(0.0055, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 51321147__2022-05-06__05d.jpg
# tensor(0.6663, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 62114332__2021-09-03__05d.jpg
# tensor(0.6526, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 1, idx : 62168416__2021-09-27__05d.jpg
# tensor(0.4884, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 62333265__2021-10-05__05d.jpg
# tensor(0.3018, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 63512162__2022-04-18__05d.jpg
# tensor(0.0055, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 63606384__2022-05-06__05d.jpg
# tensor(0.0082, grad_fn=<ToCopyBackward0>)
# True label : 0, Predicted label : 0, idx : 63760637__2022-04-28__05d.jpg
# tensor(0.6472, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 18363043__2018-09-15__205d.jpg
# tensor(0.6383, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 18363043__2018-09-15__305d.jpg
# tensor(0.7612, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 18363043__2018-09-15__405d.jpg
# tensor(0.4289, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 18363043__2018-09-15__05d.jpg
# tensor(0.5782, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 31835558__2020-06-02__05d.jpg
# tensor(0.8360, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 33071653__2019-10-07__205d.jpg
# tensor(0.8661, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 33071653__2019-10-07__05d.jpg
# tensor(0.7339, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 33818838__2018-10-16__205d.jpg
# tensor(0.7413, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 33818838__2018-10-16__305d.jpg
# tensor(0.9539, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 33818838__2018-10-16__405d.jpg
# tensor(0.7251, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 33818838__2018-10-16__05d.jpg
# tensor(0.9886, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 34427437__2019-01-04__305d.jpg
# tensor(0.4946, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 35122850__2021-09-10__205d.jpg
# tensor(0.8696, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 35122850__2021-09-10__305d.jpg
# tensor(0.7799, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 35122850__2021-09-10__05d.jpg
# tensor(0.9715, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 37022026__2018-08-29__205d.jpg
# tensor(0.9652, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 37022026__2018-08-29__305d.jpg
# tensor(0.1468, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 37022026__2018-08-29__05d.jpg
# tensor(0.4189, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 49835100__2016-04-22__205d.jpg
# tensor(0.9773, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 49835100__2016-04-22__305d.jpg
# tensor(0.5865, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 49835100__2016-04-22__05d.jpg
# tensor(0.9976, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 50526879__2016-02-12__205d.jpg
# tensor(0.9970, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 50526879__2016-02-12__05d.jpg
# tensor(0.5232, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 54374119__2018-02-13__305d.jpg
# tensor(0.3318, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 0, idx : 54374119__2018-02-13__05d.jpg
# tensor(0.9862, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 56400216__2021-02-17__205d.jpg
# tensor(0.9749, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 56400216__2021-02-17__305d.jpg
# tensor(0.9939, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 56400216__2021-02-17__405d.jpg
# tensor(0.9651, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 56400216__2021-02-17__05d.jpg
# tensor(0.7308, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 60518952__2021-08-14__205d.jpg
# tensor(0.8435, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 60518952__2021-08-14__305d.jpg
# tensor(0.7701, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 60518952__2021-08-14__05d.jpg
# tensor(0.5546, grad_fn=<ToCopyBackward0>)
# True label : 1, Predicted label : 1, idx : 53011631__2020-10-22__05d.jpg
