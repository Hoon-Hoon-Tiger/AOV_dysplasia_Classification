# %%
from PIL import Image
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np
import torchvision
from torchvision import transforms
from glob import glob
import os
import re

import shutil

# %% [markdown]
# # Internal data 누락된 정보 확인

# %%
internal_normal_path = '/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/original/internal_data/Control(normal)_img/*.jpg'
internal_abnormal_path = '/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/original/internal_data/Patient(abnormal)_img/*.jpg'

internal_nor_glob_path = glob(internal_normal_path)
internal_abnor_glob_path = glob(internal_abnormal_path)

print(len(internal_nor_glob_path))
print(len(internal_abnor_glob_path))
# Out:
# 651
# 359

# %% [markdown]
# ## renamed folder 생성

# %%
# os.makedirs('/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Control(normal)_img')
# os.makedirs('/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Patient(abnormal)_img')
renamed_normal_path = '/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Control(normal)_img'
renamed_abnormal_path = '/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Patient(abnormal)_img'

# %% [markdown]
# ### internal_normal 이름 수정해서 파일 저장

# %%
len_normal = len(internal_nor_glob_path)

bin_matrix = []

for i in range(len_normal):
    c = None
    d = None
    e = None
    f = None
    file = internal_nor_glob_path[i]
    #print(file)
    a= file.split('/')[-1]
    b= a.split('(')[-1]

    c = re.findall('05d+', b)
    d = re.findall('205d+', b)
    e = re.findall('305d+', b)
    f = re.findall('405d+', b)
    
#     print(c)
#     print(d)

    name_first = a.split('(')[0]
#한글과 영어이름을 띄어쓰기로 변환하고, 띄어쓰기를 다시 _로 변환
    korean = re.compile('[\u3131-\u3163\uac00-\ud7a3]+')
    name_first= re.sub(korean, '', name_first)
    name_first = re.sub('[a-zA-z]','',name_first).replace(' ', '_')
    name_first = re.sub(",", "", name_first)
    
# 마지막 글자가 다르거나 없는 경우가 존재하기 때문에 elif사용.    
    if d:
        name_last=d[0]
#         print(name_last)
        
    elif e:
        name_last=e[0]
        
    elif f:
        name_last=f[0]
        
    else:
        name_last=c[0]
        

    file_name = name_first+name_last+ '.jpg' 
    shutil.copy2(file, '/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Control(normal)_img/%s' % file_name)

    print(name_first+name_last)
    bin_matrix.append(file_name)
# Out:
# 10524154__2020-03-09__05d
# 10527052__2018-03-17__05d
# 10527052__2019-02-16__05d
# 10527052__2021-09-25__05d
# 10536188__2019-05-27__05d
# 10536188__2021-02-24__205d
# 10536188__2021-02-24__05d
# 10567252__2020-01-06__05d
# 10586501__2019-04-08__205d
# 10586501__2021-07-21__05d
# 10614211__2016-03-24__05d
# 10619379__2020-03-24__05d
# 10626726__2020-12-17__05d
# 10626726__2022-01-04__205d
# 10626726__2022-01-04__05d
# 10639272__2021-06-22__205d
# 10639272__2021-06-22__05d
# 10781135__2020-02-26__05d
# 10794302__2020-06-11__205d
# 10794302__2020-06-11__05d
# 10794302__2021-06-04__05d
# 10796067__2020-09-15__05d
# 60953409__2022-04-27__05d
# 62418591__2022-05-06__05d
# 62449540__2022-04-28__05d
# 62490106__2022-05-06__05d
# 62491387__2022-05-06__05d
# 62629199__2022-05-06__05d
# 62975018__2022-04-27__05d
# 62984423__2022-04-28__05d
# 63053120__2022-05-06__05d
# 63417407__2022-05-06__05d
# 63464441__2022-04-27__05d
# 63536416__2022-05-06__05d
# 63556186__2022-05-06__05d
# 63606384__2022-05-06__05d
# 63652952__2022-04-28__05d
# 63723311__2022-05-06__05d
# 63737149__2022-04-27__05d
# 63746282__2022-04-27__05d
# 63759202__2022-04-27__05d
# 63760637__2022-04-28__05d
# 63779819__2022-05-06__05d
# 63787120__2022-04-27__05d
# 63821758__2022-04-27__05d
# 63826520__2022-04-28__05d
# 63827446__2022-04-28__05d
# 63883686__2022-05-06__05d
# 10605527__2022-04-28__05d
# 10684900__2022-04-28__05d
# 10719510__2022-04-27__05d
# 11756341__2022-04-28__05d
# 11838337__2022-04-28__05d
# 12010435__2022-04-28__05d
# 12112401__2022-05-06__05d
# 12217382__2022-05-06__05d
# 12785760__2018-03-09__05d
# 10835450__2022-02-10__05d
# 13765288__2022-03-11__05d

# %% [markdown]
# ### internal_abnormal 이름 수정해서 파일 저장

# %%
len_abnormal = len(internal_abnor_glob_path)

bin_matrix = []

for i in range(len_abnormal):
    c = None
    d = None
    e = None
    f = None
    g = None
    h = None
    j = None
    k = None
    l = None
    
    file = internal_abnor_glob_path[i]
    #print(file)
    a= file.split('/')[-1]
    b= a.split('(')[-1]

    c = re.findall('05d+', b)
    d = re.findall('205d+', b)
    e = re.findall('305d+', b)
    f = re.findall('405d+', b)
    g = re.findall('505d+', b)
    h = re.findall('605d+', b)
    j = re.findall('705d+', b)
    k = re.findall('805d+', b)
    l = re.findall('905d+', b)
    
#     print(c)
#     print(d)

    name_first = a.split('(')[0]
#한글과 영어이름을 띄어쓰기로 변환하고, 띄어쓰기를 다시 _로 변환
    korean = re.compile('[\u3131-\u3163\uac00-\ud7a3]+')
    name_first= re.sub(korean, '', name_first)
    name_first = re.sub('[a-zA-z]','',name_first).replace(' ', '_')
    name_first = re.sub(",", "", name_first)
    
# 마지막 글자가 다르거나 없는 경우가 존재하기 때문에 elif사용.    

    if d:
        name_last=d[0]
#         print(name_last)
        
    elif e:
        name_last=e[0]
        
    elif f:
        name_last=f[0]
        
    elif g:
        name_last=g[0]
    
    elif h:
        name_last=h[0]
    
    elif j:
        name_last=j[0]
    
    elif k:
        name_last=k[0]
        
    elif l:
        name_last=l[0]
        
    else:
        name_last=c[0]

    file_name = name_first+name_last+ '.jpg' 
    shutil.copy2(file, '/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Patient(abnormal)_img/%s' % file_name)

    print(name_first+name_last)
    bin_matrix.append(file_name)
# Out:
# 11725493__2017-04-11__205d
# 11725493__2017-04-11__305d
# 11725493__2017-04-11__05d
# 12608236__2020-06-19__205d
# 12608236__2020-06-19__305d
# 12608236__2020-06-19__05d
# 13131359__2018-05-02__205d
# 13131359__2018-05-02__05d
# 13227717__2018-08-13__205d
# 59896373__2021-11-29__05d
# 60976781__2021-11-29__205d
# 60976781__2021-11-29__305d
# 60976781__2021-11-29__05d
# 62396514__2021-10-18__205d
# 62396514__2021-10-18__305d
# 62396514__2021-10-18__05d
# 62396514__2022-05-28__05d
# 63031593__2022-01-05__205d
# 63031593__2022-01-05__305d
# 63031593__2022-01-05__405d
# 63031593__2022-01-05__05d
# 63131501__2022-02-16__205d
# 63131501__2022-02-16__305d
# 63131501__2022-02-16__05d
# 63165883__2022-01-20__205d
# 63165883__2022-01-20__05d
# 64266765__2022-07-18__205d
# 64266765__2022-07-18__305d
# 64266765__2022-07-18__405d
# 64266765__2022-07-18__505d
# 64266765__2022-07-18__605d
# 64266765__2022-07-18__05d
# 12311811__2022-07-12__205d
# 12311811__2022-07-12__05d
# 12974988__2022-04-20__205d
# 12974988__2022-04-20__305d
# 12974988__2022-04-20__405d
# 12974988__2022-04-20__505d
# 12974988__2022-04-20__05d
# 23125779__2021-03-12__05d
# 26228886__2022-04-25__205d
# 26228886__2022-04-25__05d
# 31183505__2022-02-16__205d
# 31183505__2022-02-16__305d
# 31183505__2022-02-16__05d
# 64068529__2022-07-01__205d
# 64068529__2022-07-01__05d
# 64737476__2022-08-20__205d
# 64737476__2022-08-20__305d
# 64737476__2022-08-20__405d
# 64737476__2022-08-20__05d
# 11058371__2019-07-01__05d
# 41324194__2022-07-22__205d
# 41324194__2022-07-22__05d
# 61042489__2022-08-01__205d
# 61042489__2022-08-01__305d
# 61042489__2022-08-01__405d
# 61042489__2022-08-01__505d
# 61042489__2022-08-01__605d
# 61042489__2022-08-01__05d
# 62559485__2021-11-03__05d
# 62559485__2022-07-01__205d
# 62559485__2022-07-01__05d

# %% [markdown]
# ## 누락된 파일 정리

# %%
internal_normal_info =  pd.read_excel('/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/Patients_info_v1.xlsx', sheet_name=1, engine='openpyxl')
internal_abnormal_info =  pd.read_excel('/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/Patients_info_v1.xlsx', sheet_name=0, engine='openpyxl')

re_in_normal_glob = glob('/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Control(normal)_img/*.jpg')
re_in_abnormal_glob = glob('/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Patient(abnormal)_img/*.jpg')

# %%
# normal & abnormal excel file 환자번호 추출
df_internal_normal = internal_normal_info['환자 번호']
df_internal_normal_list = df_internal_normal.values.tolist()
df_internal_normal_str_list = list(map(str, df_internal_normal_list))

df_internal_abnormal = internal_abnormal_info['환자번호']
df_internal_abnormal_list = df_internal_abnormal.values.tolist()
df_internal_abnormal_str_list = list(map(str, df_internal_abnormal_list))

# %%
# image folder에 있는 file들의 환자 번호를 추출하는데, 중복된 경우가 존재하기 때문에 중복제거

in_nor_img_list = []
for i in range(len(re_in_normal_glob)):
    nor_patient_num = re_in_normal_glob[i].split('/')[-1].split('_')[0]
#     print(patient_num)
    in_nor_img_list.append(nor_patient_num)
in_one_nor_img_list = list(set(in_nor_img_list))


in_abnor_img_list = []
for i in range(len(re_in_abnormal_glob)):
    abnor_patient_num = re_in_abnormal_glob[i].split('/')[-1].split('_')[0]
#     print(patient_num)
    in_abnor_img_list.append(abnor_patient_num)
in_one_abnor_img_list = list(set(in_abnor_img_list))


print(len(in_one_nor_img_list))
print(len(in_one_abnor_img_list))
# Out:
# 401
# 129

# %% [markdown]
# - internal_data 상황
#
#     - normal
#     1. 현재 이미지는 존재하지만 excel file에 존재하지 않는 경우 35개의 이미지 존재
#
#     2. 현재 excel file에는 존재하지만 이미지에는 존재하지 않는 경우는 없다.
#
#     - abnormal
#     1. image folder에 존재하는 환자 수 : 129명
#
#     2. excel file에 존재하는 환자 수 : 129명 -> 하지만 excel file에는 한 환자가 다른 날짜에 관찰한 경우가 2명의 환자 존재
#         - 44205052(강효윤), 52721531(최민서)
# ----------------------------------------------------------------------------------------------------------------------
# - summary
#     - 총 이미지를 기준으로 401명이 존재하지만 excel file에 35명이 존재하지 않아 366명이 존재하고, 반대의 경우는 존재하지 않는다.
#         - internal_normal : 366명
#
#     - 누락된 abnormal image X
#         - internal_abnormal : 129명(하지만 excel file에는 한 환자가 다른 날짜에 관찰한 경우가 2명의 환자 존재)

# %% [markdown]
# ||normal|abnormal|
# |:---|---:|:---:|
# |환자수|366명|129명|
# |이미지수|612장|359장|

# %% [markdown]
# ### normal check

# %%
# normal 
internal_img_no_csv_list = []
internal_img_csv_list = []
for i in in_one_nor_img_list:
#     print(i)
#     patient_num_img = abnormal_glob[i].split('/')[-1].split('_')[0]

    if i not in df_internal_normal_str_list:
        internal_img_no_csv_list.append(i)
#         print('파일이 존재하지 않습니다:',i)
    else:
        internal_img_csv_list.append(i)
#         print('파일이 존재:',i)

#     else:
#         print('있습니다!!')
        

print('image O, excel O 환자 수 : ', len(internal_img_csv_list))

print('image O, excel X 환자 수 : ', len(internal_img_no_csv_list))
# Out:
# image O, excel O 환자 수 :  366
# image O, excel X 환자 수 :  35

# %%
internal_img_no_csv_list
# Out:
# ['62203953',
#  '62453664',
#  '35214254',
#  '11576622',
#  '20689368',
#  '54595118',
#  '39239109',
#  '62824088',
#  '21531741',
#  '12270662',
#  '29312261',
#  '18747254',
#  '55447717',
#  '36516674',
#  '29990135',
#  '62139425',
#  '62629199',
#  '28370909',
#  '60898913',
#  '12563023',
#  '18345874',
#  '10796067',
#  '17414140',
#  '56851535',
#  '25790441',
#  '12549421',
#  '19006103',
#  '11982342',
#  '11877495',
#  '10614211',
#  '18709238',
#  '54856837',
#  '53072922',
#  '52025567',
#  '32329599']

# %%
# normal
internal_csv_no_img_list = []
internal_csv_img_list = []
for i in df_internal_normal_str_list:
#     print(i)
#     patient_num_img = abnormal_glob[i].split('/')[-1].split('_')[0]

    if i not in in_one_nor_img_list:
        internal_csv_no_img_list.append(i)
#         print('파일이 존재하지 않습니다:',i)
    else:
        internal_csv_img_list.append(i)
#         print('파일이 존재:',i)

#     else:
#         print('있습니다!!')
        

print('image O, excel O 환자 수 : ', len(internal_csv_img_list))

print('image O, excel X 환자 수 : ', len(internal_csv_no_img_list))
# Out:
# image O, excel O 환자 수 :  366
# image O, excel X 환자 수 :  0

# %% [markdown]
# ### abnormal check

# %%
# abnormal 
in_abnor_img_no_csv_list = []
in_abnor_img_csv_list = []
for i in in_one_abnor_img_list:


    if i not in df_internal_abnormal_str_list:
        in_abnor_img_no_csv_list.append(i)

    else:
        in_abnor_img_csv_list.append(i)

        

print('image O, excel O 환자 수 : ', len(in_abnor_img_csv_list))

print('image O, excel X 환자 수 : ', len(in_abnor_img_no_csv_list))
# Out:
# image O, excel O 환자 수 :  129
# image O, excel X 환자 수 :  0

# %%
# abnormal 
in_abnor_csv_no_img_list = []
in_abnor_csv_img_list = []
for i in df_internal_abnormal_str_list:


    if i not in in_one_abnor_img_list:
        in_abnor_csv_no_img_list.append(i)

    else:
        in_abnor_csv_img_list.append(i)

        

print('image O, excel O 환자 수 : ', len(in_abnor_csv_img_list))

print('image O, excel X 환자 수 : ', len(in_abnor_csv_no_img_list))
# Out:
# image O, excel O 환자 수 :  133
# image O, excel X 환자 수 :  0

# %%
print(len(df_internal_abnormal_str_list))
print(len(in_one_abnor_img_list))
# Out:
# 133
# 129

# %% [markdown]
# ## 이미지만 존재하는 하는 경우 제거

# %%
a = 0
for i in range(len(re_in_normal_glob)):
    
    patient_num = re_in_normal_glob[i].split('/')[-1].split('_')[0]
    
    if patient_num not in internal_img_csv_list:
        img_path = re_in_normal_glob[i]
        os.remove(img_path)
        a += 1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-79-f0c58a7f4e87> in <module>
#       6     if patient_num not in internal_img_csv_list:
#       7         img_path = re_in_normal_glob[i]
# ----> 8         os.remove(img_path)
#       9         a += 1
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/crop2292/research_datasets/Upper_AoV_dysplasia/train_data/renamed/internal_data/Control(normal)_img/10614211__2016-03-24__05d.jpg'

# %%
nor_img_list = []
for i in range(len(re_in_normal_glob)):
    nor_patient_num = re_in_normal_glob[i].split('/')[-1].split('_')[0]
#     print(patient_num)
    nor_img_list.append(nor_patient_num)
in_one_nor_img_list = list(set(nor_img_list))

# %%
print(len(re_in_normal_glob))
print(len(in_one_nor_img_list))
# Out:
# 612
# 366

# %% [markdown]
# ## excel 존재 X, 이미지만 존재하는 경우 excel에서 제거

# %%
for i in len(df_internal_normal_list):
    patient_num = str(internal_normal_info['환자번호'][i])
    
    if patient_num not in internal_img_csv_list:
        df_drop =
# Out:
# 0      10605527
# 1      10684900
# 2      10719510
# 3      10747445
# 4      10912340
#          ...
# 361    63441215
# 362    62202936
# 363    10619379
# 364    11477174
# 365    23500673
# Name: 환자 번호, Length: 366, dtype: int64

# %%
# normal & abnormal excel file 환자번호 추출
df_internal_normal = internal_normal_info['환자 번호']
df_internal_normal_list = df_internal_normal.values.tolist()
df_internal_normal_str_list = list(map(str, df_internal_normal_list))

df_internal_abnormal = internal_abnormal_info['환자번호']
df_internal_abnormal_list = df_internal_abnormal.values.tolist()
df_internal_abnormal_str_list = list(map(str, df_internal_abnormal_list))
# Out:
# 0      10535370
# 1      11182414
# 2      11725493
# 3      12608236
# 4      13131359
#          ...
# 128    64737476
# 129    62559485
# 130    11058371
# 131    41324194
# 132    61042489
# Name: 환자번호, Length: 133, dtype: int64

# %% [markdown]
# # external data 누락된 정보 확인
